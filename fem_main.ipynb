# %%
import numpy as np
from scipy.linalg import eig
from scipy.sparse.linalg import eigsh
import matplotlib.pyplot as plt
import fem_schrodinger_1d
import importlib

importlib.reload(fem_schrodinger_1d)
from fem_schrodinger_1d import *

# %%
fem = FemSchrodinger(1e-8, np.zeros(100))

# %%
A = fem.assemble_matrix_A()
B = fem.assemble_matrix_B()

# %%
A_prime = A[1:-1, 1:-1]
B_prime = B[1:-1, 1:-1]

# %%
val, vec = eigsh(A_prime, 2, M=B_prime, which="SA")

# %%
fig, ax = plt.subplots()
ax.plot(vec)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb899d1faf0>,
#  <matplotlib.lines.Line2D at 0x7fb899d1fb20>]
